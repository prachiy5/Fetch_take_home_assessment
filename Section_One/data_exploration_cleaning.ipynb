# %%
import pandas as pd

# Load the datasets
users = pd.read_csv("USER_TAKEHOME.csv",na_values=['', ' '])
transactions = pd.read_csv("TRANSACTION_TAKEHOME.csv",na_values=['', ' '])
products=pd.read_csv('PRODUCTS_TAKEHOME.csv',na_values=['', ' '])

# %%
###  Basic Info ###
print(" USERS Dataset Info:")
users.info()
print("\n TRANSACTIONS Dataset Info:")
transactions.info()
print("\n PRODUCTS Dataset Info:")
products.info()
# Out:
#  USERS Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            100000 non-null  object
#  1   CREATED_DATE  100000 non-null  object
#  2   BIRTH_DATE    96325 non-null   object
#  3   STATE         95188 non-null   object
#  4   LANGUAGE      69492 non-null   object
#  5   GENDER        94108 non-null   object
# dtypes: object(6)
# memory usage: 4.6+ MB
#
#  TRANSACTIONS Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RECEIPT_ID      50000 non-null  object
#  1   PURCHASE_DATE   50000 non-null  object
#  2   SCAN_DATE       50000 non-null  object
#  3   STORE_NAME      50000 non-null  object
# ...

# %%
users.isnull().sum()
# Out:
# ID                  0
# CREATED_DATE        0
# BIRTH_DATE       3675
# STATE            4812
# LANGUAGE        30508
# GENDER           5892
# dtype: int64

# %%
transactions.isnull().sum()
# Out:
# RECEIPT_ID            0
# PURCHASE_DATE         0
# SCAN_DATE             0
# STORE_NAME            0
# USER_ID               0
# BARCODE            5762
# FINAL_QUANTITY        0
# FINAL_SALE        12500
# dtype: int64

# %%
products.isnull().sum()
# Out:
# CATEGORY_1         111
# CATEGORY_2        1424
# CATEGORY_3       60566
# CATEGORY_4      778093
# MANUFACTURER    226474
# BRAND           226472
# BARCODE           4025
# dtype: int64

# %%
 #users duplicate records
 users[users.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, CREATED_DATE, BIRTH_DATE, STATE, LANGUAGE, GENDER]
# Index: []

# %%
 #transactions duplicate records
 transactions[transactions.duplicated()]
# Out:
#                                  RECEIPT_ID PURCHASE_DATE  \
# 2724   1c12bd8a-c68c-41ee-a26d-294021d3e0b8    2024-09-07
# 4192   2acd7e8d-37df-4e51-8ee5-9a9c8c1d9711    2024-09-08
# 6572   431fe612-ed55-470e-939c-043ad31f33f3    2024-09-07
# 6623   43955b35-6fbc-4909-a4de-1a0de0dc387f    2024-09-06
# 7675   4ec870d2-c39f-4a40-bf8a-26a079409b20    2024-09-08
# ...                                     ...           ...
# 49651  93f45c94-af38-42d4-a3fe-eb9d5b24efbb    2024-09-03
# 49660  eee21773-6946-474a-9978-fe0659140973    2024-07-26
# 49759  01a70fe0-026f-4bea-9da4-7d13bbf21e9a    2024-09-02
# 49911  874a8116-3342-4b4a-9d24-4666e0ab1052    2024-08-31
# 49941  e0a60958-e8ef-4fa0-8b1a-5ad01dd64403    2024-07-27
#
#                        SCAN_DATE            STORE_NAME  \
# 2724   2024-09-07 15:44:35.241 Z                   CVS
# 4192   2024-09-08 11:13:01.935 Z               WALMART
# 6572   2024-09-07 16:39:01.409 Z  DOLLAR GENERAL STORE
# ...

# %%
 #products duplicate records
 products[products.duplicated()]
# Out:
#                CATEGORY_1    CATEGORY_2        CATEGORY_3 CATEGORY_4  \
# 76394              Snacks         Candy               Gum        NaN
# 87568              Snacks         Chips            Crisps        NaN
# 91710   Health & Wellness     Skin Care               NaN        NaN
# 100470             Snacks         Candy  Confection Candy        NaN
# 109639         Restaurant     Beverages              Soda  Diet Soda
# ...                   ...           ...               ...        ...
# 827242             Snacks         Candy   Chocolate Candy        NaN
# 833620             Snacks         Candy   Chocolate Candy        NaN
# 834874             Snacks  Nuts & Seeds           Peanuts        NaN
# 838643             Snacks         Candy   Chocolate Candy        NaN
# 843215             Snacks         Candy   Chocolate Candy        NaN
#
#                MANUFACTURER         BRAND     BARCODE
# 76394   THE HERSHEY COMPANY  ICE BREAKERS   3498507.0
# ...

# %% [markdown]
# **USERS DATASET CLEANING**

# %%
users.head()
# Out:
#                          ID               CREATED_DATE  \
# 0  5ef3b4f17053ab141787697d  2020-06-24 20:17:54.000 Z
# 1  5ff220d383fcfc12622b96bc  2021-01-03 19:53:55.000 Z
# 2  6477950aa55bb77a0e27ee10  2023-05-31 18:42:18.000 Z
# 3  658a306e99b40f103b63ccf8  2023-12-26 01:46:22.000 Z
# 4  653cf5d6a225ea102b7ecdc2  2023-10-28 11:51:50.000 Z
#
#                   BIRTH_DATE STATE LANGUAGE  GENDER
# 0  2000-08-11 00:00:00.000 Z    CA   es-419  female
# 1  2001-09-24 04:00:00.000 Z    PA       en  female
# 2  1994-10-28 00:00:00.000 Z    FL   es-419  female
# 3                        NaN    NC       en     NaN
# 4  1972-03-19 00:00:00.000 Z    PA       en  female

# %%
users.dtypes #check data type
# Out:
# ID              object
# CREATED_DATE    object
# BIRTH_DATE      object
# STATE           object
# LANGUAGE        object
# GENDER          object
# dtype: object

# %%
# Convert to datetime
users["CREATED_DATE"] = pd.to_datetime(users["CREATED_DATE"], errors="coerce")
print(users[["CREATED_DATE"]].head())
# Out:
#                CREATED_DATE
# 0 2020-06-24 20:17:54+00:00
# 1 2021-01-03 19:53:55+00:00
# 2 2023-05-31 18:42:18+00:00
# 3 2023-12-26 01:46:22+00:00
# 4 2023-10-28 11:51:50+00:00

# %%
# Convert to datetime
users["BIRTH_DATE"] = pd.to_datetime(users["BIRTH_DATE"], errors="coerce")
print(users[["BIRTH_DATE"]].head())
# Out:
#                  BIRTH_DATE
# 0 2000-08-11 00:00:00+00:00
# 1 2001-09-24 04:00:00+00:00
# 2 1994-10-28 00:00:00+00:00
# 3                       NaT
# 4 1972-03-19 00:00:00+00:00

# %%
users.dtypes
# Out:
# ID                           object
# CREATED_DATE    datetime64[ns, UTC]
# BIRTH_DATE      datetime64[ns, UTC]
# STATE                        object
# LANGUAGE                     object
# GENDER                       object
# dtype: object

# %%
# Standardizing categorical string values for consistency:
# - STATE: Trim leading/trailing spaces and convert to uppercase (e.g., "ca" → "CA").
# - LANGUAGE: Trim spaces and convert to lowercase (e.g., "EN " → "en").
# - GENDER: Trim spaces and convert to lowercase (e.g., " Male " → "male").

users["STATE"] = users["STATE"].str.strip().str.upper()
users["LANGUAGE"] = users["LANGUAGE"].str.strip().str.lower()
users["GENDER"] = users["GENDER"].str.strip().str.lower()

# %%
# check all values in LANGUAGE and GENDER columns
users['LANGUAGE'].unique()
users['GENDER'].unique()
# Out:
# array(['female', nan, 'male', 'non_binary', 'transgender',
#        'prefer_not_to_say', 'not_listed', 'non-binary', 'unknown',
#        'not_specified', "my gender isn't listed", 'prefer not to say'],
#       dtype=object)

# %%
# Standardizing LANGUAGE values:
# - Replacing "es-419" with "es" to ensure uniformity in language representation.
# - "es-419" refers to Latin American Spanish, but for simplicity, it is generalized to "es" (Spanish).
# - This helps maintain consistency when analyzing or grouping language-based data.

users["LANGUAGE"] = users["LANGUAGE"].replace("es-419", "es")

# Displaying the first few rows to verify changes.
users.head()
# Out:
#                          ID              CREATED_DATE  \
# 0  5ef3b4f17053ab141787697d 2020-06-24 20:17:54+00:00
# 1  5ff220d383fcfc12622b96bc 2021-01-03 19:53:55+00:00
# 2  6477950aa55bb77a0e27ee10 2023-05-31 18:42:18+00:00
# 3  658a306e99b40f103b63ccf8 2023-12-26 01:46:22+00:00
# 4  653cf5d6a225ea102b7ecdc2 2023-10-28 11:51:50+00:00
#
#                  BIRTH_DATE STATE LANGUAGE  GENDER
# 0 2000-08-11 00:00:00+00:00    CA       es  female
# 1 2001-09-24 04:00:00+00:00    PA       en  female
# 2 1994-10-28 00:00:00+00:00    FL       es  female
# 3                       NaT    NC       en     NaN
# 4 1972-03-19 00:00:00+00:00    PA       en  female

# %%
# Saving the cleaned and standardized users dataset to a CSV file.
# - `index=False` ensures that the DataFrame index is not written to the file.
users.to_csv("users_data_new.csv", index=False)

# %% [markdown]
# **TRANSACTIONS DATA CLEANING**

# %%
# Displaying the first few rows
transactions.head()
# Out:
#                              RECEIPT_ID PURCHASE_DATE  \
# 0  0000d256-4041-4a3e-adc4-5623fb6e0c99    2024-08-21
# 1  0001455d-7a92-4a7b-a1d2-c747af1c8fd3    2024-07-20
# 2  00017e0a-7851-42fb-bfab-0baa96e23586    2024-08-18
# 3  000239aa-3478-453d-801e-66a82e39c8af    2024-06-18
# 4  00026b4c-dfe8-49dd-b026-4c2f0fd5c6a1    2024-07-04
#
#                    SCAN_DATE STORE_NAME                   USER_ID  \
# 0  2024-08-21 14:19:06.539 Z    WALMART  63b73a7f3d310dceeabd4758
# 1  2024-07-20 09:50:24.206 Z       ALDI  62c08877baa38d1a1f6c211a
# 2  2024-08-19 15:38:56.813 Z    WALMART  60842f207ac8b7729e472020
# 3  2024-06-19 11:03:37.468 Z  FOOD LION  63fcd7cea4f8442c3386b589
# 4  2024-07-05 15:56:43.549 Z   RANDALLS  6193231ae9b3d75037b0f928
#
#         BARCODE FINAL_QUANTITY  FINAL_SALE
# 0  1.530001e+10           1.00         NaN
# 1           NaN           zero        1.49
# 2  7.874223e+10           1.00         NaN
# 3  7.833997e+11           zero        3.49
# ...

# %%
# Checking the data types of all columns
transactions.dtypes
# Out:
# RECEIPT_ID         object
# PURCHASE_DATE      object
# SCAN_DATE          object
# STORE_NAME         object
# USER_ID            object
# BARCODE           float64
# FINAL_QUANTITY     object
# FINAL_SALE        float64
# dtype: object

# %%
# Convert to datetime
transactions["PURCHASE_DATE"] = pd.to_datetime(transactions["PURCHASE_DATE"], errors="coerce")
print(transactions[["PURCHASE_DATE"]].head())
# Out:
#   PURCHASE_DATE
# 0    2024-08-21
# 1    2024-07-20
# 2    2024-08-18
# 3    2024-06-18
# 4    2024-07-04

# %%
# Convert to datetime
transactions["SCAN_DATE"] = pd.to_datetime(transactions["SCAN_DATE"], errors="coerce")
print(transactions[["PURCHASE_DATE"]].head())
# Out:
#   PURCHASE_DATE
# 0    2024-08-21
# 1    2024-07-20
# 2    2024-08-18
# 3    2024-06-18
# 4    2024-07-04

# %%
# Converting the BARCODE column to a string while handling missing values:
# - `float(x)`: Ensures that barcodes stored as float (e.g., 4.8001353664e+10) are converted properly.
# - `int(float(x))`: Removes decimal points from barcodes stored as floats.
# - `str(...)`: Converts the barcode to a string to maintain consistency.
# - `pd.notna(x)`: Ensures missing values (NaN) are handled and replaced with `pd.NA` instead of an error.
transactions["BARCODE"] = transactions["BARCODE"].apply(lambda x: str(int(float(x))) if pd.notna(x) else pd.NA)
transactions.head()
# Out:
#                              RECEIPT_ID PURCHASE_DATE  \
# 0  0000d256-4041-4a3e-adc4-5623fb6e0c99    2024-08-21
# 1  0001455d-7a92-4a7b-a1d2-c747af1c8fd3    2024-07-20
# 2  00017e0a-7851-42fb-bfab-0baa96e23586    2024-08-18
# 3  000239aa-3478-453d-801e-66a82e39c8af    2024-06-18
# 4  00026b4c-dfe8-49dd-b026-4c2f0fd5c6a1    2024-07-04
#
#                          SCAN_DATE STORE_NAME                   USER_ID  \
# 0 2024-08-21 14:19:06.539000+00:00    WALMART  63b73a7f3d310dceeabd4758
# 1 2024-07-20 09:50:24.206000+00:00       ALDI  62c08877baa38d1a1f6c211a
# 2 2024-08-19 15:38:56.813000+00:00    WALMART  60842f207ac8b7729e472020
# 3 2024-06-19 11:03:37.468000+00:00  FOOD LION  63fcd7cea4f8442c3386b589
# 4 2024-07-05 15:56:43.549000+00:00   RANDALLS  6193231ae9b3d75037b0f928
#
#         BARCODE FINAL_QUANTITY  FINAL_SALE
# 0   15300014978           1.00         NaN
# 1          <NA>           zero        1.49
# 2   78742229751           1.00         NaN
# ...

# %%
# Replacing empty string values in the BARCODE column with pd.NA (missing value indicator).
# - Ensures that empty values are treated as missing data rather than empty strings.
# - Helps maintain consistency in handling missing barcodes for analysis and joins.

transactions["BARCODE"] = transactions["BARCODE"].replace("", pd.NA)

# %%
## Counting the number of missing values (NaN or pd.NA) in the BARCODE column.
transactions['BARCODE'].isnull().sum()
# Out:
# 5762

# %%
# Replacing the string value "zero" with 0.00 in the FINAL_QUANTITY column.

transactions["FINAL_QUANTITY"] = transactions["FINAL_QUANTITY"].replace("zero", 0.00)

# %%
# Converting the FINAL_QUANTITY column to a numeric data type.
# - `pd.to_numeric(...)` ensures all values are properly converted to numbers.
# - `errors="coerce"` replaces non-numeric values with NaN instead of raising an error.
transactions["FINAL_QUANTITY"] = pd.to_numeric(transactions["FINAL_QUANTITY"], errors="coerce")

# %%
transactions.dtypes
# Out:
# RECEIPT_ID                     object
# PURCHASE_DATE          datetime64[ns]
# SCAN_DATE         datetime64[ns, UTC]
# STORE_NAME                     object
# USER_ID                        object
# BARCODE                        object
# FINAL_QUANTITY                float64
# FINAL_SALE                    float64
# dtype: object

# %%
num_exact_duplicates = transactions.duplicated().sum()
print(f"Total number of exact duplicate records: {num_exact_duplicates}")
# Out:
# Total number of exact duplicate records: 171

# %%
transactions = transactions.drop_duplicates(keep="first")
print(f"Total records after removing exact duplicates: {transactions.shape[0]}")
# Out:
# Total records after removing exact duplicates: 49829

# %%
print(f"Remaining duplicate records: {transactions.duplicated().sum()}")
# Out:
# Remaining duplicate records: 0

# %%
#checking if total_quantity can have decimal values

# Count how many values are whole numbers vs decimals
whole_numbers = transactions[transactions["FINAL_QUANTITY"] % 1 == 0].shape[0]
decimals = transactions[transactions["FINAL_QUANTITY"] % 1 != 0].shape[0]

print(f"\nTotal Whole Number Quantities: {whole_numbers}")
print(f"Total Decimal Quantities: {decimals}")
# Out:
# Total Whole Number Quantities: 49719
# Total Decimal Quantities: 110

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plot to see correlation between FINAL_QUANTITY and FINAL_SALE
plt.figure(figsize=(8,5))
sns.scatterplot(x=transactions["FINAL_QUANTITY"], y=transactions["FINAL_SALE"])
plt.xlabel("FINAL_QUANTITY")
plt.ylabel("FINAL_SALE")
plt.title("Relationship between Quantity and Sale Price")
plt.show()

# %%
# Find transactions where FINAL_QUANTITY is 0 but FINAL_SALE is not
zero_qty_sales = transactions[(transactions["FINAL_QUANTITY"] == 0.0) & (transactions["FINAL_SALE"] > 0)]
print(zero_qty_sales.head())
# Out:
#                              RECEIPT_ID PURCHASE_DATE  \
# 1  0001455d-7a92-4a7b-a1d2-c747af1c8fd3    2024-07-20
# 3  000239aa-3478-453d-801e-66a82e39c8af    2024-06-18
# 5  0002d8cd-1701-4cdd-a524-b70402e2dbc0    2024-06-24
# 7  00096c49-8b04-42f9-88ce-941c5e06c4a7    2024-08-19
# 9  0010d87d-1ad2-4e5e-9a25-cec736919d15    2024-08-04
#
#                          SCAN_DATE STORE_NAME                   USER_ID  \
# 1 2024-07-20 09:50:24.206000+00:00       ALDI  62c08877baa38d1a1f6c211a
# 3 2024-06-19 11:03:37.468000+00:00  FOOD LION  63fcd7cea4f8442c3386b589
# 5 2024-06-24 19:44:54.247000+00:00    WALMART  5dcc6c510040a012b8e76924
# 7 2024-08-21 17:35:21.902000+00:00     TARGET  6144f4f1f3ef696919f54b5c
# 9 2024-08-04 18:01:47.787000+00:00       ALDI  66686fc2e04f743a096ea808
#
#         BARCODE  FINAL_QUANTITY  FINAL_SALE
# 1          <NA>             0.0        1.49
# 3  783399746536             0.0        3.49
# 5  681131411295             0.0        1.46
# ...

# %%
# Check transactions with unusually high quantities
high_qty_sales = transactions[transactions["FINAL_QUANTITY"] > 100]
print(high_qty_sales.head())
# Out:
#                                  RECEIPT_ID PURCHASE_DATE  \
# 24810  fe0780d1-2d02-4822-8f12-7056b1814f17    2024-08-09
# 42410  fe0780d1-2d02-4822-8f12-7056b1814f17    2024-08-09
#
#                              SCAN_DATE          STORE_NAME  \
# 24810 2024-08-11 17:52:18.523000+00:00  MAIN STREET MARKET
# 42410 2024-08-11 17:52:18.523000+00:00  MAIN STREET MARKET
#
#                         USER_ID      BARCODE  FINAL_QUANTITY  FINAL_SALE
# 24810  5d197f9dd08976510c49d0e6  48001353664           276.0         NaN
# 42410  5d197f9dd08976510c49d0e6  48001353664           276.0        5.89

# %%
# Create a flag for transactions where quantity is 0 but sale is positive
transactions["ANOMALY_ZERO_QTY"] = (transactions["FINAL_QUANTITY"] == 0) & (transactions["FINAL_SALE"] > 0)
transactions.head()
# Out:
#                              RECEIPT_ID PURCHASE_DATE  \
# 0  0000d256-4041-4a3e-adc4-5623fb6e0c99    2024-08-21
# 1  0001455d-7a92-4a7b-a1d2-c747af1c8fd3    2024-07-20
# 2  00017e0a-7851-42fb-bfab-0baa96e23586    2024-08-18
# 3  000239aa-3478-453d-801e-66a82e39c8af    2024-06-18
# 4  00026b4c-dfe8-49dd-b026-4c2f0fd5c6a1    2024-07-04
#
#                          SCAN_DATE STORE_NAME                   USER_ID  \
# 0 2024-08-21 14:19:06.539000+00:00    WALMART  63b73a7f3d310dceeabd4758
# 1 2024-07-20 09:50:24.206000+00:00       ALDI  62c08877baa38d1a1f6c211a
# 2 2024-08-19 15:38:56.813000+00:00    WALMART  60842f207ac8b7729e472020
# 3 2024-06-19 11:03:37.468000+00:00  FOOD LION  63fcd7cea4f8442c3386b589
# 4 2024-07-05 15:56:43.549000+00:00   RANDALLS  6193231ae9b3d75037b0f928
#
#         BARCODE  FINAL_QUANTITY  FINAL_SALE  ANOMALY_ZERO_QTY
# 0   15300014978             1.0         NaN             False
# 1          <NA>             0.0        1.49              True
# ...

# %%
# Flag transactions where quantity is extremely high
transactions["ANOMALY_HIGH_QTY"] = transactions["FINAL_QUANTITY"] > 100
transactions.head()
# Out:
#                              RECEIPT_ID PURCHASE_DATE  \
# 0  0000d256-4041-4a3e-adc4-5623fb6e0c99    2024-08-21
# 1  0001455d-7a92-4a7b-a1d2-c747af1c8fd3    2024-07-20
# 2  00017e0a-7851-42fb-bfab-0baa96e23586    2024-08-18
# 3  000239aa-3478-453d-801e-66a82e39c8af    2024-06-18
# 4  00026b4c-dfe8-49dd-b026-4c2f0fd5c6a1    2024-07-04
#
#                          SCAN_DATE STORE_NAME                   USER_ID  \
# 0 2024-08-21 14:19:06.539000+00:00    WALMART  63b73a7f3d310dceeabd4758
# 1 2024-07-20 09:50:24.206000+00:00       ALDI  62c08877baa38d1a1f6c211a
# 2 2024-08-19 15:38:56.813000+00:00    WALMART  60842f207ac8b7729e472020
# 3 2024-06-19 11:03:37.468000+00:00  FOOD LION  63fcd7cea4f8442c3386b589
# 4 2024-07-05 15:56:43.549000+00:00   RANDALLS  6193231ae9b3d75037b0f928
#
#         BARCODE  FINAL_QUANTITY  FINAL_SALE  ANOMALY_ZERO_QTY  \
# 0   15300014978             1.0         NaN             False
# 1          <NA>             0.0        1.49              True
# ...

# %%
# Identify object (string) columns
string_columns = transactions.select_dtypes(include="object").columns


# Standardizing all string columns (strip spaces & lowercase)
for col in string_columns:
    transactions[col] = transactions[col].astype(str).str.strip().str.lower()

# Replace placeholders with NaN
transactions.replace(["unknown", "placeholder", "null", ""], pd.NA, inplace=True)

print(transactions[string_columns].sample(5))  # Random sample check
# Out:
#                                  RECEIPT_ID STORE_NAME  \
# 49854  1c4ac3e8-046e-4370-8509-e0403c3cb736        cvs
# 9942   663a25b5-a5c6-4a58-a50f-8d1d734dc299    walmart
# 18623  beba8d75-7f09-4577-b8aa-59ea0692cb1d    walmart
# 19447  c717f7b7-238b-4054-b5b7-cf84fa76f1c5  walgreens
# 30334  67fb5503-fe78-4230-b1ed-a397c64039ac    walmart
#
#                         USER_ID      BARCODE
# 49854  63610865a41d29ba209dcfe4         <na>
# 9942   6403f26e2a703a1959274d49  29243000103
# 18623  5bfad115de66b612c472ed9f  48564070022
# 19447  654d392ea225ea102b8112b0  49000053418
# 30334  63ff7fbd38f010745ba3bff1  24000163022

# %%
transactions["TRANSACTION_ID"] = range(1, len(transactions) + 1)
print("Duplicate Transaction_IDs:", transactions["TRANSACTION_ID"].duplicated().sum())
# Out:
# Duplicate Transaction_IDs: 0

# %%
transactions.to_csv("transactions_data_new.csv", index=False)

# %% [markdown]
# **PRODUCT DATASET CLEANING**

# %%
products.head()
# Out:
#           CATEGORY_1              CATEGORY_2                   CATEGORY_3  \
# 0  Health & Wellness           Sexual Health  Conductivity Gels & Lotions
# 1             Snacks           Puffed Snacks         Cheese Curls & Puffs
# 2  Health & Wellness               Hair Care        Hair Care Accessories
# 3  Health & Wellness               Oral Care                   Toothpaste
# 4  Health & Wellness  Medicines & Treatments               Essential Oils
#
#   CATEGORY_4                                       MANUFACTURER  \
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2        NaN                           PLACEHOLDER MANUFACTURER
# 3        NaN                                  COLGATE-PALMOLIVE
# 4        NaN  MAPLE HOLISTICS AND HONEYDEW PRODUCTS INTERCHA...
#
#              BRAND       BARCODE
# 0              NaN  7.964944e+11
# 1              NaN  2.327801e+10
# ...

# %%
products.dtypes
# Out:
# CATEGORY_1       object
# CATEGORY_2       object
# CATEGORY_3       object
# CATEGORY_4       object
# MANUFACTURER     object
# BRAND            object
# BARCODE         float64
# dtype: object

# %%
products["BARCODE"] = products["BARCODE"].apply(lambda x: str(int(float(x))) if pd.notna(x) else pd.NA)
products.head()
products['BARCODE'].isnull().sum()
# Out:
# 4025

# %%
# List of object columns to standardize
columns_to_clean = ["CATEGORY_1", "CATEGORY_2", "CATEGORY_3", "CATEGORY_4", "MANUFACTURER", "BRAND"]

# Function to clean text data
def clean_text(value):
    if pd.isna(value):  # Keep NaN values as pd.NA
        return pd.NA
    value = str(value).strip()  # Remove extra spaces
    value = value.title()  # Convert to title case (better readability)
    return value

# Apply cleaning function to all relevant columns
for col in columns_to_clean:
    products[col] = products[col].apply(clean_text)

# Verify the changes
print(products[columns_to_clean].head(10))  # Check cleaned data
# Out:
#           CATEGORY_1                  CATEGORY_2  \
# 0  Health & Wellness               Sexual Health
# 1             Snacks               Puffed Snacks
# 2  Health & Wellness                   Hair Care
# 3  Health & Wellness                   Oral Care
# 4  Health & Wellness      Medicines & Treatments
# 5  Health & Wellness                   Hair Care
# 6  Health & Wellness      Medicines & Treatments
# 7  Health & Wellness  Deodorant & Antiperspirant
# 8             Snacks                  Snack Bars
# 9  Health & Wellness                        <NA>
#
#                          CATEGORY_3 CATEGORY_4  \
# 0       Conductivity Gels & Lotions       <NA>
# 1              Cheese Curls & Puffs       <NA>
# 2             Hair Care Accessories       <NA>
# 3                        Toothpaste       <NA>
# 4                    Essential Oils       <NA>
# 5             Hair Care Accessories       <NA>
# 6     Vitamins & Herbal Supplements       <NA>
# ...

# %%
# Replace placeholder values with NaN
products["MANUFACTURER"].replace("Placeholder Manufacturer", pd.NA, inplace=True)
products["BRAND"].replace("Brand Not Known", pd.NA, inplace=True)

# Check if it worked
print(products[["MANUFACTURER", "BRAND"]].isna().sum())
# Out:
# <ipython-input-101-2f47adbf4ad5>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products["MANUFACTURER"].replace("Placeholder Manufacturer", pd.NA, inplace=True)
# <ipython-input-101-2f47adbf4ad5>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
products.isnull().sum()
# Out:
# CATEGORY_1         111
# CATEGORY_2        1424
# CATEGORY_3       60566
# CATEGORY_4      778093
# MANUFACTURER    313376
# BRAND           243497
# BARCODE           4025
# dtype: int64

# %%
products.dtypes
# Out:
# CATEGORY_1      object
# CATEGORY_2      object
# CATEGORY_3      object
# CATEGORY_4      object
# MANUFACTURER    object
# BRAND           object
# BARCODE         object
# dtype: object

# %%
# Find exact duplicates across all columns
exact_duplicates = products[products.duplicated(keep=False)]

# Display the duplicates sorted for better visibility
display(exact_duplicates.sort_values(by=products.columns.tolist()).head(20))
# Out:
#                CATEGORY_1              CATEGORY_2  \
# 183865            Alcohol                    Beer
# 359328            Alcohol                    Beer
# 695827          Beverages  Carbonated Soft Drinks
# 817261          Beverages  Carbonated Soft Drinks
# 82900   Health & Wellness  Medicines & Treatments
# 410161  Health & Wellness  Medicines & Treatments
# 764322  Health & Wellness  Medicines & Treatments
# 103494  Health & Wellness  Medicines & Treatments
# 443703  Health & Wellness  Medicines & Treatments
# 756636  Health & Wellness  Medicines & Treatments
# 342074  Health & Wellness               Skin Care
# 553131  Health & Wellness               Skin Care
# 523828  Health & Wellness               Skin Care
# 642489  Health & Wellness               Skin Care
# 2075    Health & Wellness               Skin Care
# 91710   Health & Wellness               Skin Care
# 110900  Health & Wellness                    <NA>
# 370474  Health & Wellness                    <NA>
# ...

# %%
# Count exact duplicate records
num_exact_duplicates = exact_duplicates.shape[0]

print(f"Total number of exact duplicate records: {num_exact_duplicates}")
# Out:
# Total number of exact duplicate records: 400

# %%
# Drop exact duplicates (keep first occurrence)
products = products.drop_duplicates(keep="first")

print(f"Total records after removing exact duplicates: {products.shape[0]}")
# Out:
# Total records after removing exact duplicates: 845337

# %%
# Check if any exact duplicates still exist
remaining_duplicates = products.duplicated().sum()
print(f"Remaining exact duplicate records: {remaining_duplicates}")
# Out:
# Remaining exact duplicate records: 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.heatmap(products[["CATEGORY_1", "CATEGORY_2", "CATEGORY_3", "CATEGORY_4"]].isnull(), cmap="viridis", cbar=False)
plt.title("Missing Data Heatmap for Categories")
plt.show()

# %%
products["PRODUCT_ID"] = range(1, len(products) + 1)
print("Duplicate Product_IDs:", products["PRODUCT_ID"].duplicated().sum())
# Out:
# Duplicate Product_IDs: 0

# %%
products.to_csv("products_data_new.csv", index=False)

# %%
products[products['BARCODE'].isin(transactions['BARCODE'])]
# Out:
#                CATEGORY_1           CATEGORY_2                    CATEGORY_3  \
# 103     Health & Wellness            Hair Care         Hair Styling Products
# 194     Health & Wellness            First Aid              Bandages & Gauze
# 520                Snacks              Cookies                          <NA>
# 806     Health & Wellness            Hair Care                   Conditioner
# 864                Snacks          Snack Cakes  Cakes & Truffles Snack Cakes
# ...                   ...                  ...                           ...
# 844843             Snacks                Candy               Chocolate Candy
# 844857             Snacks  Variety Snack Packs                          <NA>
# 844878  Health & Wellness       Menstrual Care           Menstrual Care Pads
# 845210             Snacks         Nuts & Seeds                       Peanuts
# 845491             Snacks                Chips                  Potato Chips
#
# ...
